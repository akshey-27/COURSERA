# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Tools for Data Science

# %% [markdown]
# ## Introduction
# This notebook introduces some of the key tools used in Data Science and demonstrate simple arithmetic operations using pyton

# %% [markdown]
# ## List Data Science Languages
# Some of the commnly used language in Data Science are:
# - Python
# - R
# - SQL
# - Scala
# - Julia

# %% [markdown]
# ## List Data Science Libraries
# Popular libraries used by Data Scientists include:
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-learn
# - TensorFolw

# %% [markdown]
# ## Data Science Tools
#
# | Tool | Description |
# |------|--------------|
# | Jupyter Notebook | An open-source web application for creating and sharing documents with live code. |
# | RStudio | An IDE for R programming language. |
# | Apache Spark | A distributed computing system for big data analytics. |

# %% [markdown]
# ## Arithmetic Expression Examples
#
# Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# Multiple and add numbers
(3*4)+5
# Out:
# 17

# %%
# Convert Minutes to Hours 

minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives
#
# After completing this notebook, you will be able to:
# - Identify popular languages for Data Science.
# - List commonly used libraries in Data Science.
# - Create tables in markdown.
# - Perform arithmetic operations in Python.
# - Convert units (e.g., minutes to hours) using code.

# %% [markdown]
# ## Author
# Akshey Kumar
